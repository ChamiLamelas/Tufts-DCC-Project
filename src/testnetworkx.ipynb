# %%
import networkx as nx
import matplotlib.pyplot as plt
import os

# %%
G = nx.DiGraph()
G.add_edge(1,2)
plt.figure()
nx.draw(G, with_labels=True)
plt.show()

# %%
import analysis as a

# %%
PATH = os.path.join("..", "data", "from_darby", "MSCallGraph_0_size100.csv")
g = a.Graphs(PATH)
len(g.microservices)
# Out:
# 12

# %%
G = nx.DiGraph()
for k, v in g.called_by_iz.items():
    for e in v:
        G.add_edge(k, e)
